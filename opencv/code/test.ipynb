# %%
import pickle

# Mở file 'encodings.pickle' để đọc dữ liệu
with open('../encodings.pickle', 'rb') as f:
    data = pickle.load(f)

# In ra nội dung của file
print(data)
# Out:
# {'encodings': [array([-0.06360261,  0.12935324, -0.0197961 , -0.05917671, -0.08870113,
#         0.00648603, -0.05450846, -0.10186964,  0.16263989, -0.06550928,
#         0.26802534, -0.01088147, -0.21264224, -0.161915  , -0.03828964,
#         0.18980454, -0.17040339, -0.15296836, -0.04288237,  0.01108493,
#         0.11137965,  0.03361396,  0.04135705,  0.03655078, -0.132194  ,
#        -0.33311653, -0.08471043, -0.1095424 , -0.00977184, -0.06186321,
#        -0.08623392,  0.04377571, -0.2007376 , -0.08554238,  0.10756694,
#         0.07034735, -0.0126786 , -0.02260062,  0.1750778 , -0.01007043,
#        -0.25058496,  0.08916358,  0.07583625,  0.2594049 ,  0.17023757,
#         0.01814845,  0.01790299, -0.17759484,  0.13465545, -0.08434264,
#         0.09942785,  0.18407014,  0.15340663,  0.03740431,  0.02829621,
#        -0.133515  ,  0.01631748,  0.13729982, -0.12108825, -0.02516961,
#         0.08379395, -0.02774394, -0.01166416, -0.09178696,  0.20777635,
# ...
